# %%
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/00350/default%20of%20credit%20card%20clients.xls
# !mv -f 'default of credit card clients.xls' 'CreditCard_Dataset.xls'
# Out:
# --2022-06-20 12:48:30--  https://archive.ics.uci.edu/ml/machine-learning-databases/00350/default%20of%20credit%20card%20clients.xls
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5539328 (5.3M) [application/x-httpd-php]
# Saving to: ‘default of credit card clients.xls’
#
# default of credit c 100%[===================>]   5.28M  10.0MB/s    in 0.5s
#
# 2022-06-20 12:48:31 (10.0 MB/s) - ‘default of credit card clients.xls’ saved [5539328/5539328]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %matplotlib inline
sns.set(style = "darkgrid")
plt.rcParams['figure.figsize'] = (15, 5)
plt.style.use('ggplot')

import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option("precision", 3)
pd.options.display.float_format = '{:.3f}'.format

# %%
pip install --upgrade xlrd
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: xlrd in /usr/local/lib/python3.7/dist-packages (1.1.0)
# Collecting xlrd
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
#      |████████████████████████████████| 96 kB 1.6 MB/s
# Installing collected packages: xlrd
#   Attempting uninstall: xlrd
#     Found existing installation: xlrd 1.1.0
#     Uninstalling xlrd-1.1.0:
#       Successfully uninstalled xlrd-1.1.0
# Successfully installed xlrd-2.0.1

# %%
df = pd.read_excel('CreditCard_Dataset.xls', header = 1, index_col = 0)
df.head(7)
# Out:
#     LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# ID
# 1       20000    2          2         1   24      2      2     -1     -1
# 2      120000    2          2         2   26     -1      2      0      0
# 3       90000    2          2         2   34      0      0      0      0
# 4       50000    2          2         1   37      0      0      0      0
# 5       50000    1          2         1   57     -1      0     -1      0
# 6       50000    1          1         2   37      0      0      0      0
# 7      500000    1          1         2   29      0      0      0      0
#
#     PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# ID         ...
# 1      -2  ...          0          0          0         0       689         0
# 2       0  ...       3272       3455       3261         0      1000      1000
# 3       0  ...      14331      14948      15549      1518      1500      1000
# 4       0  ...      28314      28959      29547      2000      2019      1200
# 5       0  ...      20940      19146      19131      2000     36681     10000
# 6       0  ...      19394      19619      20024      2500      1815       657
# 7       0  ...     542653     483003     473944     55000     40000     38000
#
#     PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ID
# 1          0         0         0                           1
# 2       1000         0      2000                           1
# 3       1000      1000      5000                           0
# 4       1100      1069      1000                           0
# 5       9000       689       679                           0
# 6       1000      1000       800                           0
# 7      20239     13750     13770                           0
#
# [7 rows x 24 columns]

# %%
df.shape
# Out:
# (30000, 24)

# %%
df.columns
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30000 entries, 1 to 30000
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   LIMIT_BAL                   30000 non-null  int64
#  1   SEX                         30000 non-null  int64
#  2   EDUCATION                   30000 non-null  int64
#  3   MARRIAGE                    30000 non-null  int64
#  4   AGE                         30000 non-null  int64
#  5   PAY_0                       30000 non-null  int64
#  6   PAY_2                       30000 non-null  int64
#  7   PAY_3                       30000 non-null  int64
#  8   PAY_4                       30000 non-null  int64
#  9   PAY_5                       30000 non-null  int64
#  10  PAY_6                       30000 non-null  int64
#  11  BILL_AMT1                   30000 non-null  int64
#  12  BILL_AMT2                   30000 non-null  int64
#  13  BILL_AMT3                   30000 non-null  int64
#  14  BILL_AMT4                   30000 non-null  int64
#  15  BILL_AMT5                   30000 non-null  int64
#  16  BILL_AMT6                   30000 non-null  int64
#  17  PAY_AMT1                    30000 non-null  int64
#  18  PAY_AMT2                    30000 non-null  int64
#  19  PAY_AMT3                    30000 non-null  int64
#  20  PAY_AMT4                    30000 non-null  int64
#  21  PAY_AMT5                    30000 non-null  int64
#  22  PAY_AMT6                    30000 non-null  int64
#  23  default payment next month  30000 non-null  int64
# dtypes: int64(24)
# memory usage: 5.7 MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30000 entries, 1 to 30000
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   LIMIT_BAL                   30000 non-null  int64
#  1   SEX                         30000 non-null  int64
#  2   EDUCATION                   30000 non-null  int64
#  3   MARRIAGE                    30000 non-null  int64
#  4   AGE                         30000 non-null  int64
#  5   PAY_0                       30000 non-null  int64
#  6   PAY_2                       30000 non-null  int64
#  7   PAY_3                       30000 non-null  int64
#  8   PAY_4                       30000 non-null  int64
#  9   PAY_5                       30000 non-null  int64
#  10  PAY_6                       30000 non-null  int64
#  11  BILL_AMT1                   30000 non-null  int64
#  12  BILL_AMT2                   30000 non-null  int64
#  13  BILL_AMT3                   30000 non-null  int64
#  14  BILL_AMT4                   30000 non-null  int64
#  15  BILL_AMT5                   30000 non-null  int64
#  16  BILL_AMT6                   30000 non-null  int64
#  17  PAY_AMT1                    30000 non-null  int64
#  18  PAY_AMT2                    30000 non-null  int64
#  19  PAY_AMT3                    30000 non-null  int64
#  20  PAY_AMT4                    30000 non-null  int64
#  21  PAY_AMT5                    30000 non-null  int64
#  22  PAY_AMT6                    30000 non-null  int64
#  23  default payment next month  30000 non-null  int64
# dtypes: int64(24)
# memory usage: 5.7 MB

# %%
df["default payment next month"].value_counts(normalize = True)
# Out:
# 0   0.779
# 1   0.221
# Name: default payment next month, dtype: float64

# %%
df["MARRIAGE"].value_counts(normalize = True)
# Out:
# 2   0.532
# 1   0.455
# 3   0.011
# 0   0.002
# Name: MARRIAGE, dtype: float64

# %%
from numpy import unique

counts = df.nunique() 

for_deletion = [i for i,v in enumerate(counts) if v == 1]

if for_deletion == []:
  print('Numbers of the useless columns are: empty ') #it means all our columns are useful

else:
  print('Numbers of the useless columns are:', for_deletion)

df.drop(for_deletion, axis = 1, inplace = True)

print('\nDimensionalities of our dataset after dropping are:', '\n', 'objects (clients) = ', '\t', '\t', df.shape[0],
      '\n', 'features (column names) = ', '\t', df.shape[1])

if (df.shape[0] == 30000) and (df.shape[1] == 24):
  print('\nAs a result, dimensionalities of our dataset after the dropping process have not changed.\n')

print("Numbers of unique values for each column and its percent (%):\n")
print('Nr \t UV \t %')

print('======================')

for i in range(df.shape[1]):
    num = len(unique(df.iloc[:, i]))
    percentage = float(num) / df.shape[0] * 100
    print('%d\t %d\t %.1f' % (i, num, percentage))

print('======================')
# Out:
# Numbers of the useless columns are: empty
#
# Dimensionalities of our dataset after dropping are:
#  objects (clients) =  	 	 30000
#  features (column names) =  	 24
#
# As a result, dimensionalities of our dataset after the dropping process have not changed.
#
# Numbers of unique values for each column and its percent (%):
#
# Nr 	 UV 	 %
# ======================
# 0	 81	 0.3
# 1	 2	 0.0
# 2	 7	 0.0
# 3	 4	 0.0
# 4	 56	 0.2
# 5	 11	 0.0
# 6	 11	 0.0
# 7	 11	 0.0
# 8	 11	 0.0
# 9	 10	 0.0
# 10	 10	 0.0
# 11	 22723	 75.7
# 12	 22346	 74.5
# 13	 22026	 73.4
# 14	 21548	 71.8
# 15	 21010	 70.0
# 16	 20604	 68.7
# 17	 7943	 26.5
# 18	 7899	 26.3
# 19	 7518	 25.1
# 20	 6937	 23.1
# 21	 6897	 23.0
# 22	 6939	 23.1
# 23	 2	 0.0
# ======================

# %%
df.corr().style.background_gradient(cmap = 'BuPu')
# Out:
# <style type="text/css">
# #T_477fb_row0_col0, #T_477fb_row1_col1, #T_477fb_row2_col2, #T_477fb_row3_col3, #T_477fb_row4_col4, #T_477fb_row5_col5, #T_477fb_row6_col6, #T_477fb_row7_col7, #T_477fb_row8_col8, #T_477fb_row9_col9, #T_477fb_row10_col10, #T_477fb_row11_col11, #T_477fb_row12_col12, #T_477fb_row13_col13, #T_477fb_row14_col14, #T_477fb_row15_col15, #T_477fb_row16_col16, #T_477fb_row17_col17, #T_477fb_row18_col18, #T_477fb_row19_col19, #T_477fb_row20_col20, #T_477fb_row21_col21, #T_477fb_row22_col22, #T_477fb_row23_col23 {
#   background-color: #4d004b;
#   color: #f1f1f1;
# }
# #T_477fb_row0_col1 {
#   background-color: #e4eef5;
#   color: #000000;
# }
# #T_477fb_row0_col2, #T_477fb_row0_col5, #T_477fb_row0_col6, #T_477fb_row0_col7, #T_477fb_row0_col8, #T_477fb_row0_col9, #T_477fb_row0_col10, #T_477fb_row0_col23, #T_477fb_row1_col11, #T_477fb_row1_col12, #T_477fb_row1_col13, #T_477fb_row1_col14, #T_477fb_row3_col4, #T_477fb_row3_col13, #T_477fb_row3_col14, #T_477fb_row3_col15, #T_477fb_row3_col16, #T_477fb_row4_col1, #T_477fb_row4_col3, #T_477fb_row5_col17, #T_477fb_row5_col18, #T_477fb_row5_col19, #T_477fb_row5_col20, #T_477fb_row5_col21, #T_477fb_row5_col22, #T_477fb_row6_col0, #T_477fb_row6_col17, #T_477fb_row7_col18, #T_477fb_row8_col19, #T_477fb_row23_col21 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_477fb_row0_col3, #T_477fb_row3_col10, #T_477fb_row17_col16, #T_477fb_row22_col19 {
#   background-color: #c8daea;
#   color: #000000;
# }
# #T_477fb_row0_col4, #T_477fb_row15_col7, #T_477fb_row16_col6, #T_477fb_row16_col7, #T_477fb_row21_col0, #T_477fb_row22_col0 {
#   background-color: #9bb6d7;
#   color: #000000;
# }
# #T_477fb_row0_col11, #T_477fb_row0_col14, #T_477fb_row2_col7, #T_477fb_row6_col3, #T_477fb_row9_col23, #T_477fb_row17_col4, #T_477fb_row20_col15, #T_477fb_row21_col4 {
#   background-color: #afc8e0;
#   color: #000000;
# }
# #T_477fb_row0_col12, #T_477fb_row0_col13, #T_477fb_row10_col16, #T_477fb_row13_col17 {
#   background-color: #b2cae1;
#   color: #000000;
# }
# #T_477fb_row0_col15, #T_477fb_row7_col3, #T_477fb_row8_col3, #T_477fb_row19_col4, #T_477fb_row19_col14 {
#   background-color: #aec7e0;
#   color: #000000;
# }
# #T_477fb_row0_col16, #T_477fb_row5_col3, #T_477fb_row10_col15, #T_477fb_row18_col4, #T_477fb_row19_col17, #T_477fb_row20_col4, #T_477fb_row22_col4 {
#   background-color: #b0c9e1;
#   color: #000000;
# }
# #T_477fb_row0_col17, #T_477fb_row2_col10, #T_477fb_row6_col4, #T_477fb_row7_col4, #T_477fb_row8_col4, #T_477fb_row8_col16, #T_477fb_row9_col4 {
#   background-color: #bed2e6;
#   color: #000000;
# }
# #T_477fb_row0_col18, #T_477fb_row7_col11, #T_477fb_row9_col11, #T_477fb_row10_col11, #T_477fb_row17_col22, #T_477fb_row20_col18 {
#   background-color: #c4d7e8;
#   color: #000000;
# }
# #T_477fb_row0_col19, #T_477fb_row0_col22, #T_477fb_row5_col4, #T_477fb_row8_col13, #T_477fb_row8_col14, #T_477fb_row9_col13, #T_477fb_row17_col13, #T_477fb_row19_col20 {
#   background-color: #bcd1e5;
#   color: #000000;
# }
# #T_477fb_row0_col20, #T_477fb_row9_col12, #T_477fb_row10_col12, #T_477fb_row17_col14 {
#   background-color: #bfd3e6;
#   color: #000000;
# }
# #T_477fb_row0_col21, #T_477fb_row6_col11, #T_477fb_row6_col12, #T_477fb_row7_col12, #T_477fb_row8_col15, #T_477fb_row9_col2, #T_477fb_row10_col4, #T_477fb_row10_col13, #T_477fb_row14_col18, #T_477fb_row16_col17, #T_477fb_row20_col17 {
#   background-color: #bdd1e5;
#   color: #000000;
# }
# #T_477fb_row1_col0, #T_477fb_row3_col6, #T_477fb_row3_col7, #T_477fb_row7_col13, #T_477fb_row8_col12, #T_477fb_row10_col2, #T_477fb_row17_col20, #T_477fb_row19_col16, #T_477fb_row22_col17 {
#   background-color: #c0d4e6;
#   color: #000000;
# }
# #T_477fb_row1_col2, #T_477fb_row2_col3, #T_477fb_row5_col16, #T_477fb_row12_col2, #T_477fb_row13_col20, #T_477fb_row17_col9, #T_477fb_row17_col21, #T_477fb_row19_col10, #T_477fb_row20_col6, #T_477fb_row21_col7, #T_477fb_row21_col11, #T_477fb_row22_col7 {
#   background-color: #cedfec;
#   color: #000000;
# }
# #T_477fb_row1_col3, #T_477fb_row7_col2, #T_477fb_row19_col15 {
#   background-color: #bacfe4;
#   color: #000000;
# }
# #T_477fb_row1_col4, #T_477fb_row3_col5, #T_477fb_row3_col9, #T_477fb_row8_col11, #T_477fb_row13_col22, #T_477fb_row16_col18, #T_477fb_row18_col20 {
#   background-color: #c5d8e9;
#   color: #000000;
# }
# #T_477fb_row1_col5, #T_477fb_row1_col7, #T_477fb_row4_col8, #T_477fb_row17_col11, #T_477fb_row18_col7, #T_477fb_row22_col10 {
#   background-color: #d4e3ef;
#   color: #000000;
# }
# #T_477fb_row1_col6, #T_477fb_row15_col2, #T_477fb_row16_col2, #T_477fb_row20_col12, #T_477fb_row21_col9 {
#   background-color: #d3e2ef;
#   color: #000000;
# }
# #T_477fb_row1_col8, #T_477fb_row20_col5, #T_477fb_row21_col15 {
#   background-color: #d7e5f0;
#   color: #000000;
# }
# #T_477fb_row1_col9, #T_477fb_row1_col10, #T_477fb_row18_col2, #T_477fb_row20_col9, #T_477fb_row21_col10 {
#   background-color: #d9e6f1;
#   color: #000000;
# }
# #T_477fb_row1_col15, #T_477fb_row3_col11, #T_477fb_row3_col12, #T_477fb_row6_col18, #T_477fb_row7_col0, #T_477fb_row10_col21, #T_477fb_row23_col13, #T_477fb_row23_col18 {
#   background-color: #f6fbfc;
#   color: #000000;
# }
# #T_477fb_row1_col16, #T_477fb_row9_col20, #T_477fb_row23_col17, #T_477fb_row23_col20, #T_477fb_row23_col22 {
#   background-color: #f6fbfd;
#   color: #000000;
# }
# #T_477fb_row1_col17, #T_477fb_row4_col13, #T_477fb_row4_col21, #T_477fb_row7_col17, #T_477fb_row9_col19, #T_477fb_row10_col20, #T_477fb_row19_col1 {
#   background-color: #e9f2f8;
#   color: #000000;
# }
# #T_477fb_row1_col18, #T_477fb_row3_col19, #T_477fb_row8_col17, #T_477fb_row8_col18, #T_477fb_row9_col18, #T_477fb_row14_col1 {
#   background-color: #ebf4f8;
#   color: #000000;
# }
# #T_477fb_row1_col19, #T_477fb_row1_col20, #T_477fb_row2_col11, #T_477fb_row3_col18, #T_477fb_row12_col1 {
#   background-color: #edf5f9;
#   color: #000000;
# }
# #T_477fb_row1_col21, #T_477fb_row1_col22, #T_477fb_row3_col1, #T_477fb_row3_col21, #T_477fb_row11_col1 {
#   background-color: #eef5f9;
#   color: #000000;
# }
# #T_477fb_row1_col23, #T_477fb_row4_col17 {
#   background-color: #e5eff6;
#   color: #000000;
# }
# #T_477fb_row2_col0, #T_477fb_row3_col2, #T_477fb_row10_col18, #T_477fb_row13_col1 {
#   background-color: #ecf4f9;
#   color: #000000;
# }
# #T_477fb_row2_col1 {
#   background-color: #e6f0f6;
#   color: #000000;
# }
# #T_477fb_row2_col4, #T_477fb_row5_col23, #T_477fb_row14_col9, #T_477fb_row15_col9 {
#   background-color: #98b0d3;
#   color: #000000;
# }
# #T_477fb_row2_col5, #T_477fb_row2_col8, #T_477fb_row10_col23, #T_477fb_row16_col20, #T_477fb_row18_col19, #T_477fb_row19_col18 {
#   background-color: #b3cbe2;
#   color: #000000;
# }
# #T_477fb_row2_col6, #T_477fb_row4_col2, #T_477fb_row8_col23, #T_477fb_row21_col16 {
#   background-color: #acc6df;
#   color: #000000;
# }
# #T_477fb_row2_col9, #T_477fb_row6_col2, #T_477fb_row9_col16, #T_477fb_row12_col3, #T_477fb_row16_col3 {
#   background-color: #b7cee3;
#   color: #000000;
# }
# #T_477fb_row2_col12, #T_477fb_row3_col20, #T_477fb_row3_col22, #T_477fb_row10_col0 {
#   background-color: #eef6fa;
#   color: #000000;
# }
# #T_477fb_row2_col13, #T_477fb_row2_col18, #T_477fb_row9_col0 {
#   background-color: #f1f7fa;
#   color: #000000;
# }
# #T_477fb_row2_col14, #T_477fb_row2_col22, #T_477fb_row6_col21, #T_477fb_row6_col22, #T_477fb_row7_col1, #T_477fb_row7_col21, #T_477fb_row7_col22, #T_477fb_row8_col0, #T_477fb_row8_col21 {
#   background-color: #f3f9fc;
#   color: #000000;
# }
# #T_477fb_row2_col15, #T_477fb_row2_col21, #T_477fb_row5_col0, #T_477fb_row6_col1, #T_477fb_row6_col20, #T_477fb_row7_col19, #T_477fb_row7_col20, #T_477fb_row8_col20, #T_477fb_row23_col12, #T_477fb_row23_col15 {
#   background-color: #f4fafc;
#   color: #000000;
# }
# #T_477fb_row2_col16, #T_477fb_row6_col19, #T_477fb_row23_col11, #T_477fb_row23_col14, #T_477fb_row23_col16, #T_477fb_row23_col19 {
#   background-color: #f5fafc;
#   color: #000000;
# }
# #T_477fb_row2_col17, #T_477fb_row10_col1 {
#   background-color: #f0f7fa;
#   color: #000000;
# }
# #T_477fb_row2_col19, #T_477fb_row5_col1, #T_477fb_row8_col1, #T_477fb_row8_col22 {
#   background-color: #f2f8fb;
#   color: #000000;
# }
# #T_477fb_row2_col20, #T_477fb_row9_col21 {
#   background-color: #f3f9fb;
#   color: #000000;
# }
# #T_477fb_

# %%
df_example = pd.DataFrame(df, columns=df.columns.tolist()[0:6])
df_example.head()
# Out:
#     LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0
# ID
# 1       20000    2          2         1   24      2
# 2      120000    2          2         2   26     -1
# 3       90000    2          2         2   34      0
# 4       50000    2          2         1   37      0
# 5       50000    1          2         1   57     -1

# %%
df_unique = pd.DataFrame(df, columns=df.columns.tolist()[11:23])
df_unique.head()
# Out:
#     BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  \
# ID
# 1        3913       3102        689          0          0          0
# 2        2682       1725       2682       3272       3455       3261
# 3       29239      14027      13559      14331      14948      15549
# 4       46990      48233      49291      28314      28959      29547
# 5        8617       5670      35835      20940      19146      19131
#
#     PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6
# ID
# 1          0       689         0         0         0         0
# 2          0      1000      1000      1000         0      2000
# 3       1518      1500      1000      1000      1000      5000
# 4       2000      2019      1200      1100      1069      1000
# 5       2000     36681     10000      9000       689       679

# %%
f = plt.figure(figsize=(17, 12))

plt.matshow(df_unique.corr(), fignum=f.number)

plt.xticks(range(df_unique.shape[1]), df_unique.columns, fontsize=14, rotation=45)

plt.yticks(range(df_unique.shape[1]), df_unique.columns, fontsize=14)

cb = plt.colorbar()

cb.ax.tick_params(labelsize=14)

plt.title('Correlation Matrix\n\n', fontsize=16)
# Out:
# Text(0.5, 1.05, 'Correlation Matrix\n\n')

# %%
df_ALB = pd.DataFrame(df, columns=['LIMIT_BAL','AGE'])
sns.jointplot(x='AGE', y='LIMIT_BAL', data = df_ALB)

# %%
df_LBP = pd.DataFrame(df, columns=['LIMIT_BAL','PAY_AMT5'])
sns.jointplot(x='PAY_AMT5',y='LIMIT_BAL',data = df_LBP)

# %%
print("Part of clients =", '{:.2%}'.format(df["default payment next month"].mean()))
# Out:
# Part of clients = 22.12%

# %%
df[df["default payment next month"] == 1].mean()
# Out:
# LIMIT_BAL                    130109.656
# SEX                               1.567
# EDUCATION                         1.895
# MARRIAGE                          1.528
# AGE                              35.726
# PAY_0                             0.668
# PAY_2                             0.458
# PAY_3                             0.362
# PAY_4                             0.255
# PAY_5                             0.168
# PAY_6                             0.112
# BILL_AMT1                     48509.162
# BILL_AMT2                     47283.618
# BILL_AMT3                     45181.599
# BILL_AMT4                     42036.951
# BILL_AMT5                     39540.190
# BILL_AMT6                     38271.436
# PAY_AMT1                       3397.044
# PAY_AMT2                       3388.650
# PAY_AMT3                       3367.352
# PAY_AMT4                       3155.627
# PAY_AMT5                       3219.140
# PAY_AMT6                       3441.482
# default payment next month        1.000
# dtype: float64

# %%
ars = round(df[df["default payment next month"] == 1]["PAY_2"].mean(), 2) * 100

print("The typical client's average repayment status in September 2005 was= ", ars, "%")
# Out:
# The typical client's average repayment status in September 2005 was=  46.0 %

# %%
pd = round(((df["default payment next month"] == 1).sum() & df["PAY_0"].value_counts()[-1]) / df.shape[0], 3)*100
print("Part of clients =", pd, "%")
# Out:
# Part of clients = 13.8 %

# %%
sns.displot(df, x = "LIMIT_BAL", col = "SEX", multiple = "dodge")

# %%
sns.displot(df, x = "LIMIT_BAL", hue = "MARRIAGE", kind = "kde", multiple = "stack")

# %%
g = sns.PairGrid(df[['SEX', 'EDUCATION', 'MARRIAGE', 'AGE']])
g.map_upper(sns.histplot)
g.map_lower(sns.kdeplot, fill=True)
g.map_diag(sns.histplot, kde=True)

# %%
df["AGE"].hist(bins = 50)

# %%
df.hist(color = "k",
        bins = 30,
        figsize = (15, 15))
plt.show()

# %%
sns.set_theme(style = "whitegrid")
sns.boxplot(x = "EDUCATION",
                 y = "LIMIT_BAL",
                 hue = "SEX",
                 data = df,
                 linewidth = 2.0,
                 dodge = True,
                 palette = "Set2")

# %%
sns.boxplot(x = "MARRIAGE",
                 y = "AGE",
                 hue = "SEX",
                 data = df,
                 linewidth = 2.0,
                 dodge = True,
                 palette = "Set3")
